# %% [markdown]
# Generating different types of toy data

# %%
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt
import numpy as np

from sklearn.datasets.samples_generator import make_blobs
X, labels = make_blobs(n_samples=50, centers=10, n_features=7, random_state=5)
print(X.shape)

ytdist = X
Z = hierarchy.linkage(ytdist, 'single')
plt.figure()
dn = hierarchy.dendrogram(Z)
# Out:
# (200, 7)

# %%
from sklearn.cluster import DBSCAN
# Compute DBSCAN
db = DBSCAN(eps=5.0, metric='euclidean', min_samples=2).fit(X)
db.labels_
# Out:
# array([0, 1, 2, 3, 0, 4, 3, 5, 0, 4, 0, 6, 3, 7, 8, 9, 7, 5, 3, 8, 8, 0,
#        1, 0, 5, 6, 1, 2, 8, 5, 0, 5, 5, 6, 4, 4, 5, 7, 5, 8, 1, 0, 8, 4,
#        1, 4, 8, 7, 3, 6, 8, 7, 6, 8, 2, 0, 5, 4, 1, 6, 0, 1, 7, 7, 9, 4,
#        4, 4, 3, 0, 8, 5, 3, 7, 7, 3, 5, 1, 1, 3, 9, 4, 4, 1, 0, 2, 6, 7,
#        9, 2, 5, 1, 7, 5, 9, 1, 3, 0, 3, 3, 4, 9, 2, 7, 4, 3, 9, 6, 3, 0,
#        7, 1, 4, 9, 8, 7, 6, 6, 2, 4, 6, 2, 2, 4, 0, 6, 2, 5, 6, 8, 2, 2,
#        6, 4, 7, 6, 7, 9, 8, 2, 0, 5, 3, 2, 0, 7, 5, 5, 8, 1, 1, 5, 6, 7,
#        5, 9, 8, 0, 7, 9, 0, 5, 9, 3, 1, 1, 2, 2, 9, 1, 9, 2, 3, 6, 9, 9,
#        9, 1, 6, 2, 0, 8, 9, 1, 4, 8, 8, 4, 9, 3, 9, 8, 3, 8, 3, 6, 2, 2,
#        6, 7])

# %%
import hdbscan
clusterer = hdbscan.HDBSCAN(min_cluster_size=3, gen_min_span_tree=True)
clusterer.fit(X)

clusterer.minimum_spanning_tree_.plot(edge_cmap='viridis',
                                      edge_alpha=0.6,
                                      node_size=80,
                                      edge_linewidth=2)

# %%
clusterer.condensed_tree_.plot()
